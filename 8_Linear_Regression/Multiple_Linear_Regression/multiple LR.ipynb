# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error , r2_score
from sklearn.datasets import make_regression

# %%
x,y = make_regression(n_samples = 100 , n_features = 2 , n_informative = 2 , n_targets = 1,noise = 50)

# %%
df = pd.DataFrame({'feature1' : x[:,0],'feature2':x[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0  0.881754  1.297577   34.768986
# 1 -0.408015 -0.203835   47.616320
# 2 -0.592459 -1.408547 -101.662279
# 3  0.214830  0.670729  101.144941
# 4 -0.606256 -1.111262  -98.596951

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,2]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 0)

# %%
y_train = pd.DataFrame(y_train)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict (x_test)

# %%
print('MSE : ',mean_squared_error(y_pred,y_test))
print('MAE : ',mean_absolute_error(y_pred,y_test))
print('R2_score : ',r2_score(y_pred,y_test))
# Out:
# MSE :  2954.1793857174725
# MAE :  43.90813196481003
# R2_score :  0.4593244385003846

# %%
lr.coef_
# Out:
# array([[ 5.40449543, 66.96071363]])

# %%
lr.intercept_
# Out:
# array([-3.67883275])
