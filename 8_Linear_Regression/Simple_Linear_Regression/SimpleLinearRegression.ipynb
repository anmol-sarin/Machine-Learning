# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df.sample(10)
# Out:
#      cgpa  package
# 163  8.93     3.91
# 30   7.36     3.26
# 73   8.44     4.03
# 148  7.57     3.40
# 55   8.20     3.39
# 134  7.20     2.83
# 188  7.35     3.08
# 119  7.39     2.65
# 162  5.53     2.55
# 23   6.19     2.48

# %%
plt.scatter(df['cgpa'],df['package'])

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.iloc[:,0:1]
y = df['package']
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2 , random_state = 0)

# %%
x_test
# Out:
#      cgpa
# 18   6.94
# 170  6.22
# 107  6.33
# 98   7.69
# 177  7.09
# 182  5.88
# 5    7.89
# 146  6.07
# 12   8.94
# 152  7.37
# 61   5.48
# 125  7.33
# 180  6.19
# 154  7.08
# 80   7.63
# 7    6.75
# 33   6.35
# 130  6.68
# 37   5.90
# 74   6.85
# 183  7.28
# 145  5.84
# 45   7.87
# 159  8.71
# 60   5.61
# 123  5.10
# 179  7.14
# 185  6.31
# 122  5.12
# 44   5.09
# 16   6.84
# 55   8.20
# 150  6.30
# 111  5.42
# 22   6.14
# 189  8.11
# 129  7.29
# 4    6.94
# 83   8.44
# 106  6.13

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_test
# Out:
# 18     2.98
# 170    2.87
# 107    2.59
# 98     3.83
# 177    3.64
# 182    2.08
# 5      2.99
# 146    2.46
# 12     3.65
# 152    3.08
# 61     1.61
# 125    3.16
# 180    2.72
# 154    2.85
# 80     3.44
# 7      2.48
# 33     2.73
# 130    2.49
# 37     2.43
# 74     3.44
# 183    2.72
# 145    2.18
# 45     3.58
# 159    4.08
# 60     2.19
# 123    2.30
# 179    3.03
# 185    3.18
# 122    2.01
# 44     1.86
# 16     2.35
# 55     3.39
# 150    2.73
# 111    2.25
# 22     2.30
# 189    4.06
# 129    3.12
# 4      3.57
# 83     3.49
# 106    2.19
# Name: package, dtype: float64

# %%
y_pred
# Out:
# array([2.97012606, 2.55516816, 2.61856451, 3.40237388, 3.05657563,
#        2.35921582, 3.51763996, 2.4687186 , 4.1227869 , 3.21794814,
#        2.12868365, 3.19489493, 2.53787825, 3.05081232, 3.36779405,
#        2.86062328, 2.63009112, 2.82028015, 2.37074243, 2.91825632,
#        3.1660784 , 2.3361626 , 3.50611335, 3.9902309 , 2.20360661,
#        1.90967809, 3.08539215, 2.6070379 , 1.9212047 , 1.90391479,
#        2.91249302, 3.69630239, 2.60127459, 2.09410383, 2.50906173,
#        3.64443265, 3.17184171, 2.97012606, 3.83462169, 2.50329842])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color = 'red')

# %%
# showing the m(slope) and b(intercept) value
m = lr.coef_
b = lr.intercept_

# %%
m , b
# Out:
# (array([0.57633042]), -1.0296070415163103)

# %%
# showing the value of full equation
# y = mx + c
m*6.22 + b
# Out:
# array([2.55516816])

# %%
m*100 + b
# Out:
# array([56.6034348])

# %%
m*7.8 + b
# Out:
# array([3.46577022])
